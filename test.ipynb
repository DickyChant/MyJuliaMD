# %%
using Plots

# %%
include("md_utils.jl")
# Out:
# -0.00036429867657183663

# %%
plot(PE_lj,0.9,5)

# %%
x = [1,14]
y = [1,10]
z = [1,8]

vx = [0,0]
vy = [0,0]
vz = [0,0]

fx = [0,0]
fy = [0,0]
fz = [0,0]
# Out:
# 1×2 Array{Int64,2}:
#  0  0

# %%
print(PE_all(x,y,z))
# Out:
# -8.922471052050356e-7

# %%
print(KE_all(vx,vy,vz))
# Out:
# 0.0

# %%
fx,fy,fz = updateForce(x,y,z)
# Out:
# ([-1.0257632054329198e-7, 1.0257632054329198e-7], [-3.077289616298759e-7, 3.077289616298759e-7], [-4.103052821731679e-7, 4.103052821731679e-7])

# %%
vx = updateVelosity(vx,fx)
vy = updateVelosity(vy,fy)
vz = updateVelosity(vz,fz)
# Out:
# 2×2 Array{Float64,2}:
#  -2.05153e-12  -2.05153e-12
#   2.05153e-12   2.05153e-12

# %%
vx
# Out:
# 2×2 Array{Float64,2}:
#  -5.12882e-13  -5.12882e-13
#   5.12882e-13   5.12882e-13

# %%
fx
# Out:
# 2-element Array{Float64,1}:
#  -1.0257632054329198e-7
#   1.0257632054329198e-7
